# %% [markdown]
# # Building the Recommender System (Matrix Factorization)
#
# ### Intuition
#
# The intuition behind using matrix factorization to solve this problem is that there should be some latent features that determine how a user rates an item. For example, two users would give high ratings to a certain movie if they both like the actors or actresses in the movie, or if the movie is an action movie, which is a genre preferred by both users.
#
# Hence, if we can discover these latent features, we should be able to predict a rating with respect to a certain user and a certain item, because the features associated with the user should match with the features associated with the item.
#
# ### Workflow
#
# 1. Read in data
# 2. Create utility (user and product interaction) matrix.
# 3. Using MF class, create 2 latent features matrices (P and Q).
# 4. Use gradient descent to lower the root mean squared error (RMSE).
# 5. Score predictions based on total final RMSE and Recall.

# %%
# Import standard libraries
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import sqlite3
from collections import Counter
from time import sleep
import time

sns.set_style('whitegrid')

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %% [markdown]
# ### 1. Read in Data

# %%
# Read in Data
sqlite_db = 'datasets/amzn_vg_clean.db'
conn = sqlite3.connect(sqlite_db) 

query = '''
SELECT "customer_id", "product_title", "star_rating"
FROM video_games
'''

sample = pd.read_sql(query, con=conn)

# %%
# Matrix of user ratings for each product
ratings_df = sample.groupby(['customer_id','product_title'])['star_rating'].mean().unstack()
ratings_df = ratings_df.fillna(0)
ratings_df.head()
# Out:
# product_title  007 Legends  007 The World Is Not Enough PS  \
# customer_id
# 11049                  0.0                             0.0
# 86525                  0.0                             0.0
# 100864                 0.0                             0.0
# 452646                 0.0                             0.0
# 1132227                0.0                             0.0
#
# product_title  007 The World is Not Enough  10 Minute Solution  \
# customer_id
# 11049                                  0.0                 0.0
# 86525                                  0.0                 0.0
# 100864                                 0.0                 0.0
# 452646                                 0.0                 0.0
# 1132227                                0.0                 5.0
#
# product_title  100 All-Time Favorites - Nintendo DS  \
# customer_id
# 11049                                           0.0
# 86525                                           0.0
# 100864                                          0.0
# 452646                                          0.0
# 1132227                                         0.0
#
# product_title  100 Classic Books - Nintendo DS  \
# customer_id
# 11049                                      0.0
# 86525                                      0.0
# 100864                                     0.0
# 452646                                     0.0
# 1132227                                    0.0
#
# product_title  1001 Touch Games - Nintendo DS  \
# customer_id
# 11049                                     0.0
# 86525                                     0.0
# 100864                                    0.0
# 452646                                    0.0
# 1132227                                   0.0
#
# product_title  101-in-1 Explosive Megamix - Nintendo DS  1080 Snowboarding  \
# customer_id
# 11049                                               0.0                0.0
# 86525                                               0.0                0.0
# 100864                                              0.0                0.0
# 452646                                              0.0                0.0
# 1132227                                             0.0                0.0
#
# product_title  1080° Avalanche  ...  iCarly - Nintendo DS  \
# customer_id                     ...
# 11049                      0.0  ...                   0.0
# 86525                      0.0  ...                   0.0
# 100864                     0.0  ...                   0.0
# 452646                     0.0  ...                   0.0
# 1132227                    0.0  ...                   0.0
#
# product_title  inFAMOUS - Playstation 3  inFAMOUS 2  \
# customer_id
# 11049                               0.0         0.0
# 86525                               0.0         0.0
# 100864                              0.0         0.0
# 452646                              0.0         0.0
# 1132227                             0.0         0.0
#
# product_title  inFAMOUS Collection - Playstation 3  \
# customer_id
# 11049                                          0.0
# 86525                                          0.0
# 100864                                         0.0
# 452646                                         0.0
# 1132227                                        0.0
#
# product_title  inFAMOUS Second Son - PlayStation 4  \
# customer_id
# 11049                                          5.0
# 86525                                          0.0
# 100864                                         0.0
# 452646                                         0.0
# 1132227                                        0.0
#
# product_title  inFAMOUS: Second Son Collector's Edition - PlayStation 4  \
# customer_id
# 11049                                                        0.0
# 86525                                                        0.0
# 100864                                                       0.0
# 452646                                                       0.0
# 1132227                                                      0.0
#
# product_title  inFAMOUS: Second Son Limited Edition (PlayStation 4)  \
# customer_id
# 11049                                                        0.0
# 86525                                                        0.0
# 100864                                                       0.0
# 452646                                                       0.0
# 1132227                                                      0.0
#
# product_title  inFamous First Light - PS4 (Physical Version)  \
# customer_id
# 11049                                                    0.0
# 86525                                                    0.0
# 100864                                                   0.0
# 452646                                                   0.0
# 1132227                                                  0.0
#
# product_title  miCoach by Adidas  rFactor V. 1.255 - PC
# customer_id
# 11049                        0.0                    0.0
# 86525                        0.0                    0.0
# 100864                       0.0                    0.0
# 452646                       0.0                    0.0
# 1132227                      0.0                    0.0
#
# [5 rows x 4669 columns]

# %%
ratings_df.shape
# Out:
# (1996, 4669)

# %% [markdown]
# ### 2. Matrix Factorization Class

# %%
class MF():

    def __init__(self, R, K, alpha, beta, iterations):
        '''
        Perform matrix factorization to predict empty entries in a matrix.
        
        Arguments:
        - R (ndarray)   : user-item rating matrix
        - K (int)       : number of latent dimensions
        - alpha (float) : learning rate
        - beta (float)  : regularization parameter
        '''

        self.R = R
        self.num_users, self.num_items = R.shape
        self.K = K
        self.alpha = alpha
        self.beta = beta
        self.iterations = iterations

    def train(self):
        '''
        Function that trains MF model based on how many iterations.
        
        Process:
        1. Initialize user and item latent features matrices.
        2. Initialize global, user and item biases.
        3. Implement gradient descent.
        4. Calculate RMSE at each interation.
        '''
        # Initialize user and item latent feature matrice
        self.P = np.random.normal(scale=1./self.K, size=(self.num_users, self.K))
        self.Q = np.random.normal(scale=1./self.K, size=(self.num_items, self.K))

        # Initialize the biases
        self.b_u = np.zeros(self.num_users)
        self.b_i = np.zeros(self.num_items)
        self.b = np.mean(self.R[np.where(self.R != 0)])

        # Create a list of training samples
        self.samples = [
            (u, i, self.R[u, i]) 
            for u in range(self.num_users) 
            for i in range(self.num_items) 
            if self.R[u, i] > 0
        ]

        # Perform stochastic gradient descent for number of iterations
        training_process = []
        for i in range(self.iterations):
            np.random.shuffle(self.samples)
            self.sgd()
#             print('sgd ok')
            mse = self.mse()
#             print('mse ok')
            training_process.append((i, mse))
            if (i+1) % 100 == 0:
                print("Iteration: %d ; rmse = %.4f" % (i+1, mse))

        return training_process

    def mse(self):
        '''
        A function to compute the total mean square error
        '''
        xs, ys = self.R.nonzero()
        predicted = self.full_matrix()
        error = 0
        for x, y in zip(xs, ys):
            error += pow(self.R[x, y] - predicted[x, y], 2)
        return np.sqrt(error)

    def sgd(self):
        '''
        Perform stochastic graident descent
        '''
        for u, i, r in self.samples:
            # Compute prediction and error
            prediction = self.get_rating(u, i)
            e = (r - prediction)

            # Update biases
            self.b_u[u] += self.alpha * (e - self.beta * self.b_u[u])
            self.b_i[i] += self.alpha * (e - self.beta * self.b_i[i])
#             print('ok')

            # Update user and item latent feature matrices
            self.P[u, :] += self.alpha * (e * self.Q[i, :] - self.beta * self.P[u,:])
            self.Q[i, :] += self.alpha * (e * self.P[u, :] - self.beta * self.Q[i,:])
#             print('ok')

    def get_rating(self, u, i):
        '''
        Get the predicted rating of user i and item j
        '''
        prediction = self.b + self.b_u[u] + self.b_i[i] + self.P[u, :].dot(self.Q[i, :].T)
        return prediction

    def full_matrix(self):
        '''
        Compute the full matrix using the resultant biases, P and Q
        '''
        return self.b + self.b_u[:,np.newaxis] + self.b_i[np.newaxis:,] + self.P.dot(self.Q.T)

# %% [markdown]
# **NEW**

# %%
class MF():

    def __init__(self, R, K, alpha, beta, iterations):
        '''
        Perform matrix factorization to predict empty entries in a matrix.
        
        Arguments:
        - R (ndarray)   : user-item rating matrix
        - K (int)       : number of latent dimensions
        - alpha (float) : learning rate
        - beta (float)  : regularization parameter
        '''

        self.R = R
        self.num_users, self.num_items = R.shape
        self.K = K
        self.alpha = alpha
        self.beta = beta
        self.iterations = iterations

    def train(self):
        '''
        Function that trains MF model based on how many iterations.
        
        Process:
        1. Initialize user and item latent features matrices.
        2. Initialize global, user and item biases.
        3. Implement gradient descent.
        4. Calculate RMSE at each interation.
        '''
        # Initialize user and item latent feature matrice
        self.P = np.random.normal(scale=1./self.K, size=(self.num_users, self.K))
        self.Q = np.random.normal(scale=1./self.K, size=(self.num_items, self.K))

        # Initialize the biases
#         self.b_u = np.zeros(self.num_users)
        self.b_i = np.zeros(self.num_items)
        self.b = np.mean(self.R[np.where(self.R != 0)])

        # Create a list of training samples
        self.samples = [
            (u, i, self.R[u, i]) 
            for u in range(self.num_users) 
            for i in range(self.num_items) 
            if self.R[u, i] > 0
        ]

        # Perform stochastic gradient descent for number of iterations
        training_process = []
        for i in range(self.iterations):
            np.random.shuffle(self.samples)
            self.sgd()
#             mse = self.mse()
#             training_process.append((i, mse))
#             if (i+1) % 100 == 0:
#                 print("Iteration: %d ; rmse = %.4f" % (i+1, mse))

        return training_process

#     def mse(self):
#         '''
#         A function to compute the total mean square error
#         '''
#         xs, ys = self.R.nonzero()
#         predicted = [self.get_rating(xs, ys) for xs, ys in zip(xs, ys)]
#         error = 0
#         for x, y, p in zip(xs, ys, predicted):
#             error += pow(self.R[x, y] - p, 2)
#         return np.sqrt(error)

    def sgd(self):
        '''
        Perform stochastic graident descent
        '''
        for u, i, r in self.samples:
            # Compute prediction and error
            prediction = self.get_rating(u, i)
            e = (r - prediction)

            # Update biases
#             self.b_u[u] += self.alpha * (e - self.beta * self.b_u[u])
            self.b_i[i] += self.alpha * (e - self.beta * self.b_i[i])

            # Update user and item latent feature matrices
            self.P[u, :] += self.alpha * (e * self.Q[i, :] - self.beta * self.P[u,:])
            self.Q[i, :] += self.alpha * (e * self.P[u, :] - self.beta * self.Q[i,:])

    def get_rating(self, u, i):
        '''
        Get the predicted rating of user i and item j
        '''
        prediction = self.b + self.b_i[i] + self.P[u, :].dot(self.Q[i, :].T)
        return prediction

    def full_matrix(self):
        '''
        Compute the full matrix using the resultant biases, P and Q
        '''
        return self.b + self.b_i[np.newaxis:,] + self.P.dot(self.Q.T)

# %% [markdown]
# ### 3. Train Matrix Factorization Model

# %%
# Define R
R = ratings_df.values

# Initialize the matrix factorization calss
mf = MF(R, K=2, alpha=0.01, beta=0.01, iterations=500)

# Note - for bigger datasets, alpha=0.1 creates a problem with matrix multiplication
# Reduce alpha to solve this problem

# %%
# Time training time
start = time.time()

# Train model
training_procc = mf.train()

end = time.time()
print('Time taken: {} seconds'.format(end - start))
# Out:
# Time taken: 345.47141194343567 seconds

# %%
iterations = [itr[0] for itr in training_procc]
rmse = [score[1] for score in training_procc]

plt.figure(figsize=(10,8))
plt.plot(iterations, rmse)
plt.title('RMSE - 1000 Iterations', pad=20, fontsize=20)
plt.xlabel('Iterations', labelpad=20, fontsize=15)
plt.ylabel('RMSE', labelpad=20, fontsize=15)

# %% [markdown]
# **Closer Look at our Model**

# %%
# Latent Features for customers
print(mf.P.shape)

P_latent_features = pd.DataFrame(mf.P, 
                                 index=ratings_df.index, 
                                 columns=['Latent Feature 1','Latent Feature 2'])

P_latent_features.head()

# %%
# Latent Features for items 
print(mf.Q.shape)

Q_latent_features = pd.DataFrame(mf.Q, 
                                 index=ratings_df.columns, 
                                 columns=['Latent Feature 1','Latent Feature 2'])

Q_latent_features.head()

# %%
Q_latent_features['diff'] = Q_latent_features['Latent Feature 1'] - Q_latent_features['Latent Feature 2']
Q_latent_features.describe()

# %%
Q_latent_features[Q_latent_features['diff']>0]

# %%
Q_latent_features[Q_latent_features['diff']<0]

# %%
# User bias
print(mf.b_u.shape)

user_bias = pd.DataFrame(mf.b_u, index=ratings_df.index, columns=['User Bias'])
user_bias

# %%
# Item bias
print(mf.b_i.shape)

item_bias = pd.DataFrame(mf.b_i, index=ratings_df.columns, columns=['Item Bias'])
item_bias

# %% [markdown]
# **Compare to Predictions to Original**

# %%
pd.DataFrame(mf.full_matrix(), index=ratings_df.index, columns=ratings_df.columns).head()

# %%
ratings_df.head()

# %%
mf.mse()

# %%
def mse(true, preds):
    '''
    A function that computes total root mean squared error.
    '''
    xs, ys = true.nonzero()
    error = 0
    for x, y in zip(xs, ys):
        error += (true[x, y] - preds[x, y])**2
        print(true[x, y], preds[x, y])
    return np.sqrt(error)

# %%
mse(ratings_df.values, mf.full_matrix())

# %% [markdown]
# ### 5. Make Recommendations for New Customer

# %%
def get_recommendations(new_ratings, utilmat, K=2, alpha=0.05, beta=0.02, iterations=500):
    '''
    Function that gets recommendation for a new customer.
    
    Arguments:
    - new_ratings   : Dictionary of new customer's items and ratings
    - utilmat       : Utility matrix
    - K             : Number of latent features
    - alpha         : Learning rate 
    - beta          : Regularization parameter
    - iterations    : Number of iterations
    '''
    # Add new customer to utility matrix
    new_customer = pd.DataFrame([new_ratings], columns=utilmat.columns).fillna(0)
    new_utilmat = pd.concat([new_customer, utilmat])
    
    # Define R
    R = new_utilmat.values

    # Initialize the matrix factorization calss
    mf = MF(R, K=K, alpha=alpha, beta=beta, iterations=iterations)
    
    # Train model
    start = time.time()
    training_procc = mf.train()
    end = time.time()
    print('Time taken: {} seconds'.format(end - start))
    
    # Make new Dataframe with new customer
    preds = pd.DataFrame(mf.full_matrix(), index=new_utilmat.index, columns=new_utilmat.columns)
    
    print('\nBased on your preferences:\n', new_ratings, '\nWe Suggest:')

    return preds.loc[0].sort_values(ascending=False).head(15)

# %%
# Count how many times each product appears in the entire dataset
prod_freq_sample = Counter([prod for prod in sample['product_title'].values])
sorted(prod_freq_sample.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('The Last of Us', 203),
#  ('Grand Theft Auto V', 183),
#  ('Grand Theft Auto IV', 180),
#  ('Call of Duty: Ghosts', 177),
#  ("Assassin's Creed 4", 175),
#  ('Watch Dogs', 155),
#  ('Call of Duty 4: Modern Warfare', 148),
#  ('Elder Scrolls V: Skyrim', 147),
#  ('Destiny', 147),
#  ('Mass Effect 3', 139),
#  ('Dead Space', 139),
#  ("Assassin's Creed III", 137),
#  ('Mortal Kombat', 135),
#  ('BioShock', 134),
#  ('Nintendo Amiibo', 134),
#  ("Assassin's Creed", 132),
#  ('Tomb Raider', 131),
#  ('Fallout 3', 130),
#  ('Mass Effect 2', 130),
#  ('Battlefield 3', 124),
#  ('Call of Duty: Modern Warfare 2', 124),
#  ('Borderlands', 119),
#  ('Red Dead Redemption', 118),
#  ('Resident Evil 5', 117),
#  ('Dead Space 2', 117),
#  ('Resident Evil 6', 116),
#  ('Injustice: Gods Among Us', 115),
#  ('Max Payne 3', 113),
#  ('Star Wars: The Force Unleashed', 112),
#  ('Assassins Creed II', 111),
#  ('Batman Arkham Origins', 110),
#  ('LA Noire', 108),
#  ('Batman Arkham City', 107),
#  ('Battlefield 4', 107),
#  ('God of War III', 106),
#  ('BioShock Infinite', 105),
#  ('Borderlands 2', 105),
#  ('Metal Gear Solid 4: Guns of the Patriots', 103),
#  ("Uncharted: Drake's Fortune - Playstation 3", 103),
#  ('Grand Theft Auto: Vice City', 103),
#  ('Batman: Arkham Asylum', 102),
#  ('Halo 3', 102),
#  ('Mass Effect - Xbox 360 (Limited)', 100),
#  ("Uncharted 3: Drake's Deception", 99),
#  ('Far Cry 3', 98),
#  ('Castlevania: Lords of Shadow', 98),
#  ('Kingdom Hearts', 98),
#  ('The Elder Scrolls IV: Oblivion', 98),
#  ('Disney INFINITY Disney Infinity: Marvel Super Heroes (2.0 Edition) Characters',
#   97),
#  ('Dishonored', 97),
#  ('Call of Duty: World at War', 97),
#  ('Bioshock 2', 97),
#  ('Super Smash Brothers', 94),
#  ('God of War: Ascension', 94),
#  ("Tom Clancy's Splinter Cell Blacklist", 92),
#  ('Grand Theft Auto: San Andreas', 91),
#  ('Halo 4', 90),
#  ('Crysis 2', 90),
#  ('Titanfall', 90),
#  ('Fallout New Vegas', 90),
#  ('Dark Souls', 90),
#  ('Call of Duty: Black Ops II', 88),
#  ('Rage', 88),
#  ("Assassin's Creed: Brotherhood", 87),
#  ('Killzone: Shadow Fall (PlayStation 4)', 87),
#  ('Dragon Age: Origins', 87),
#  ('Grand Theft Auto III - PS2', 87),
#  ('Gears Of War - Xbox 360', 86),
#  ("Dante's Inferno", 86),
#  ('Wolfenstein: The New Order', 86),
#  ('Uncharted 2: Among Thieves - Playstation 3', 86),
#  ('Rayman Legends', 85),
#  ('Halo 2', 84),
#  ('Middle Earth: Shadow of Mordor', 83),
#  ('Dragon Age 2', 83),
#  ('Dragon Age Inquisition', 82),
#  ('Batman Arkham Asylum Goty', 82),
#  ('LEGO: Marvel', 82),
#  ('Dead Space 3', 81),
#  ('Gears of War 3', 80),
#  ('Far Cry 4', 80),
#  ('Doom 3', 79),
#  ('Devil May Cry', 78),
#  ('Tomb Raider: Definitive Edition', 78),
#  ("Demon's Souls", 78),
#  ('Max Payne', 78),
#  ('Left 4 Dead - Nintendo 64', 78),
#  ("Assassin's Creed Revelations", 77),
#  ('Halo Reach', 77),
#  ('Resident Evil: Revelations', 76),
#  ('Fallout 3: Game of The Year Edition', 76),
#  ("Tom Clancy's Splinter Cell", 76),
#  ('Call of Duty: Advanced Warfare', 75),
#  ('Battlefield: Bad Company 2', 75),
#  ('Killzone 3', 75),
#  ('The Evil Within', 74),
#  ('Portal 2', 74),
#  ('Medal of Honor', 74),
#  ('Killzone 2 - Playstation 3', 74),
#  ('Sleeping Dogs', 73),
#  ("Assassin's Creed Unity", 73),
#  ('inFAMOUS - Playstation 3', 73),
#  ('Heavy Rain - Greatest Hits', 73),
#  ('Fable III', 72),
#  ('Batman: Arkham City Game of the Year Edition', 71),
#  ('Metal Gear Rising Revengeance', 71),
#  ('Diablo III - PC/Mac', 71),
#  ('Crysis 3', 70),
#  ('Darksiders', 70),
#  ('Lego Batman', 69),
#  ('Resident Evil', 69),
#  ('Call of Duty: Modern Warfare 3 - Xbox 360', 68),
#  ('Aliens: Colonial Marines', 67),
#  ('Guitar Hero III: Legends of Rock', 67),
#  ('The Legend of Zelda: Twilight Princess', 67),
#  ('Super Mario 3D Land', 67),
#  ('Duke Nukem Forever', 67),
#  ('Gears of War 2', 67),
#  ('Metal Gear Solid 2: Sons of Liberty', 66),
#  ('Halo 3: ODST', 66),
#  ('New Super Mario Bros', 66),
#  ('The Order: 1886', 65),
#  ('Minecraft - Xbox 360', 65),
#  ('Hitman: Absolution', 65),
#  ('Dark Souls 2', 64),
#  ('Super Mario Galaxy', 63),
#  ('The Legend of Zelda: The Wind Waker', 63),
#  ('Call of Duty: Black Ops - Xbox 360', 63),
#  ('Kingdoms of Amalur: Reckoning', 63),
#  ('Super Smash Bros Melee', 63),
#  ('Need for Speed: Hot Pursuit', 63),
#  ('Prince of Persia', 63),
#  ('Nintendo DS Lite', 63),
#  ('Bloodborne', 62),
#  ('Thief', 62),
#  ('Call of Duty: Black Ops - Playstation 3', 62),
#  ('Need for Speed Rivals', 62),
#  ('Super Mario Sunshine', 62),
#  ('StarCraft II', 62),
#  ('Rayman Origins', 62),
#  ('Enslaved: Odyssey to the West', 62),
#  ('Fable 2', 62),
#  ('Resident Evil: Operation Raccoon City', 61),
#  ('The Legend of Zelda: Ocarina of Time 3D', 61),
#  ('New Super Mario Bros. U', 60),
#  ('Prototype', 60),
#  ('Bayonetta', 60),
#  ('Metroid Prime', 60),
#  ('Resistance: Fall of Man - Playstation 3', 59),
#  ('Mario Kart 7', 59),
#  ('Super Smash Bros. Brawl', 59),
#  ('The Orange Box - Nintendo 64', 58),
#  ('God Of War Collection', 58),
#  ('Sonic Generations', 57),
#  ('New Super Mario Bros. 2', 57),
#  ('Alan Wake', 57),
#  ('PlayStation All-Stars Battle Royale', 57),
#  ('God of War - PlayStation 2', 57),
#  ('Homefront', 56),
#  ('Mortal Kombat vs. DC Universe', 56),
#  ('Left 4 Dead 2', 56),
#  ('Need for Speed Most Wanted', 55),
#  ('Spec Ops: The Line', 55),
#  ('Bulletstorm', 55),
#  ('Burnout Paradise - Nintendo 64', 55),
#  ('Resident Evil 2', 55),
#  ('Dying Light', 54),
#  ('Dead Rising 2', 54),
#  ('Just Cause 2', 54),
#  ("Tom Clancy's Splinter Cell Conviction", 54),
#  ('Lego Indiana Jones: The Original Adventures', 54),
#  ('Shadow of the Colossus', 54),
#  ('The Legend of Zelda: A Link to the Past', 54),
#  ('Ghostbusters: The Video Game', 54),
#  ('Lego Star Wars: The Complete Saga', 54),
#  ('Prince of Persia: The Forgotten Sands', 54),
#  ('Fable: The Lost Chapters', 54),
#  ('Xbox One with Kinect (Day One Edition)', 53),
#  ("Tom Clancy's Ghost Recon Future Soldier", 53),
#  ('Donkey Kong Country Returns', 53),
#  ("Mirror's Edge", 53),
#  ('Medal of Honor: Warfighter', 53),
#  ('Saints Row the Third', 52),
#  ('F.E.A.R. 2: Project Origin', 52),
#  ('Saints Row 4', 52),
#  ('Resistance 3', 52),
#  ('Wolfenstein', 52),
#  ('Mortal Kombat Komplete Edition', 51),
#  ('Far Cry 2', 51),
#  ('F.E.A.R. 3', 51),
#  ("Tom Clancy's Rainbow Six Vegas", 51),
#  ('Resident Evil 4', 51),
#  ('inFAMOUS: Second Son Limited Edition (PlayStation 4)', 51),
#  ('Devil May Cry 4', 51),
#  ('Star Wars Knights of the Old Republic - Xbox', 51),
#  ('Toy Story 3 The Video Game', 50),
#  ('Resistance 2', 50),
#  ('Binary Domain', 50),
#  ('Alice: Madness Returns', 50),
#  ('Mafia II', 50),
#  ('Guitar Hero World Tour', 50),
#  ('Batman: Arkham Knight', 49),
#  ('Sonic and All-Stars Racing Transformed Bonus Edition', 49),
#  ('Resident Evil 4 - Gamecube', 49),
#  ('Star Wars: The Force Unleashed II Platinum Edition', 49),
#  ('FIFA Soccer 13', 49),
#  ('Star Wars Battlefront II', 49),
#  ('GameCube (Jet Black)', 49),
#  ('BEYOND: Two Souls', 48),
#  ('Call Of Duty 3', 48),
#  ('Red Faction Guerrilla', 48),
#  ('Vanquish', 48),
#  ('Saints Row 2', 47),
#  ('Call of Duty: Black Ops', 47),
#  ('LEGO Lord of the Rings', 47),
#  ('Alien: Isolation', 47),
#  ('Sly Cooper: Thieves in Time', 47),
#  ('Lego Star Wars II: The Original Trilogy', 47),
#  ('Lego Pirates Of Caribbean', 47),
#  ('Sonic the Hedgehog', 47),
#  ('Donkey Kong Country', 47),
#  ('Darksiders II', 47),
#  ('Uncharted: Golden Abyss', 47),
#  ('F.E.A.R. First Encounter Assault Recon', 47),
#  ('Tekken 6', 47),
#  ('Catherine', 47),
#  ('Metal Gear Solid HD Collection', 46),
#  ('Disney Epic Mickey 2: The Power of Two', 46),
#  ('Ni no Kuni: Wrath of the White Witch', 46),
#  ('Call of Duty 2', 46),
#  ('Knack (PlayStation 4)', 46),
#  ('Call of Duty: Modern Warfare 3 - Playstation 3', 46),
#  ('Street Fighter IV', 46),
#  ('Infamous 2 - Playstation 3', 46),
#  ('Dead Rising - Xbox 360', 45),
#  ('The Witcher 3: Wild Hunt', 45),
#  ('Halo: The Master Chief Collection', 45),
#  ('Resident Evil 4 - PlayStation 2', 45),
#  ('Alpha Protocol', 45),
#  ('Tomb Raider Underworld', 45),
#  ('The Legend of Zelda: A Link Between Worlds 3D Twister Parent', 45),
#  ('Need For Speed: Most Wanted', 45),
#  ('James Bond 007: Nightfire', 44),
#  ('Star Wars Knights of the Old Republic II: The Sith Lords', 44),
#  ('The LEGO Movie Videogame', 44),
#  ('Super Mario 64 DS', 44),
#  ('Prototype 2', 44),
#  ('Silent Hill: Homecoming', 43),
#  ('Lego Batman 2 Super Hero', 43),
#  ('Sonic Mega Collection', 43),
#  ("Tom Clancy's Rainbow Six Vegas 2", 43),
#  ('Rock Band 2', 43),
#  ('Animal Crossing', 43),
#  ('Crazy Taxi', 43),
#  ('Hyrule Warriors', 42),
#  ('Sonic Unleashed', 42),
#  ("Luigi's Mansion - Gamecube", 42),
#  ('The Legend of Zelda: The Wind Waker HD', 42),
#  ('Mario Kart DS', 42),
#  ("Dragon's Crown", 42),
#  ('Singularity', 42),
#  ('Remember Me', 42),
#  ('World of Warcraft - Obsolete', 42),
#  ('The Elder Scrolls V: Skyrim Legendary Edition', 42),
#  ('Silent Hill 3', 42),
#  ('X-Men Origins: Wolverine', 42),
#  ('Crysis', 42),
#  ('Soul Calibur II', 42),
#  ('Metal Gear Solid', 41),
#  ('Metroid: Other M', 41),
#  ('Army of Two - Nintendo 64', 41),
#  ('Gears of War: Judgment', 41),
#  ('Super Mario World', 41),
#  ('Timeshift', 41),
#  ('Need for Speed: Carbon', 41),
#  ('Soul Calibur IV', 41),
#  ('Kingdom Hearts II - PlayStation 2', 41),
#  ('The Legend of Zelda: Ocarina of Time', 41),
#  ('Hitman 2 Silent Assassin', 41),
#  ('Pokmon Omega Ruby', 40),
#  ('Animal Crossing: New Leaf', 40),
#  ('Half-Life 2 - PC', 40),
#  ('Red Dead Redemption Game of the Year', 40),
#  ('Alien vs Predator', 40),
#  ('Prince of Persia: The Sands of Time', 40),
#  ('Red Faction Armageddon', 40),
#  ('Gran Turismo 5', 40),
#  ('NBA 2K14', 40),
#  ('Shadows of the Damned', 40),
#  ('Doom 3 BFG Edition', 40),
#  ('Manhunt', 40),
#  ('The Darkness', 40),
#  ('Red Faction', 40),
#  ('XCOM: Enemy Unknown', 39),
#  ('Bond 007: Quantum of Solace', 39),
#  ('Call of Duty: Black Ops II - PlayStation 3', 39),
#  ('Madden NFL 13', 39),
#  ('Dead Island', 39),
#  ('Nintendo DS', 39),
#  ('Devil May Cry Collection', 39),
#  ('Need for Speed: Underground', 39),
#  ('Heavenly Sword - Playstation 3', 39),
#  ('Silent Hill 2', 39),
#  ('Dark Sector', 39),
#  ('Resident Evil Zero - Gamecube', 39),
#  ('inFAMOUS Second Son - PlayStation 4', 38),
#  ('The ICO and Shadow of the Colossus Collection', 38),
#  ('Teenage Mutant Ninja Turtles', 38),
#  ('Mario Kart: Super Circuit', 38),
#  ('Michael Jackson The Experience', 38),
#  ('Street Fighter X Tekken', 38),
#  ('Super Mario 64', 38),
#  ('Brink', 38),
#  ('LittleBigPlanet - Playstation 3', 38),
#  ('Just Dance 2014', 38),
#  ('God of War Origins Collection - Playstation 3', 38),
#  ('Gran Turismo 3 A-spec', 38),
#  ('Dragon Quest VIII: Journey of the Cursed King', 38),
#  ('Sonic Adventure 2 Battle - GameCube', 38),
#  ('Battlefield Hardline', 37),
#  ('Grand Theft Auto: Episodes from Liberty City', 37),
#  ('Marvel vs. Capcom 3: Fate of Two Worlds', 37),
#  ('Ratchet & Clank Future: A Crack in Time', 37),
#  ('Fire Emblem: Awakening', 37),
#  ('James Bond 007 Everything or Nothing', 37),
#  ('Chrono Cross - PlayStation', 37),
#  ('Madden NFL 25', 37),
#  ('Mario Kart: Double Dash', 37),
#  ('Silent Hill: Downpour', 37),
#  ('Tomb Raider Legend', 37),
#  ('Ninja Gaiden Sigma', 37),
#  ('Elder Scrolls III: Morrowind', 37),
#  ('Disney Epic Mickey', 36),
#  ('Plants vs. Zombies Garden Warfare', 36),
#  ('Bravely Default - Nintendo 3DS', 36),
#  ('LEGO Harry Potter: Years 1-4', 36),
#  ('James Bond 007 Agent Under Fire', 36),
#  ('Super Mario World: Super Mario Advance 2', 36),
#  ('Rocksmith 2014', 36),
#  ('Transformers: Cybertron Adventures', 36),
#  ('Mercenaries 2: World in Flames - Nintendo 64', 36),
#  ('The Sims 2', 36),
#  ('Medal of Honor Frontline - PlayStation 2', 36),
#  ("Luigi's Mansion: Dark Moon", 35),
#  ("Sniper Elite III: Collector's Edition - PlayStation 4 Collector's Edition",
#   35),
#  ('Dead Rising 3', 35),
#  ('The Legend of Zelda: Skyward Sword with Music CD', 35),
#  ('Gun', 35),
#  ('Super Mario Galaxy 2', 35),
#  ('Syndicate', 35),
#  ("WWE '13", 35),
#  ('The Amazing Spider-Man', 35),
#  ('The Witcher 2: Assassins Of Kings Enhanced Edition', 35),
#  ('The Saboteur', 35),
#  ('Alone in the Dark', 35),
#  ('Silent Hill Origins', 35),
#  ('Pokemon Y', 35),
#  ("Dragon's Dogma", 35),
#  ('Need For Speed : The Run', 35),
#  ('FIFA 14', 35),
#  ('Batman Vengeance', 35),
#  ('PlayStation 3', 35),
#  ("Tony Hawk's Pro Skater 3", 35),
#  ('LittleBigPlanet', 34),
#  ('Splatterhouse', 34),
#  ('Mortal Kombat Trilogy', 34),
#  ('DeadPool', 34),
#  ("Tom Clancy's Ghost Recon Advanced Warfighter 2", 34),
#  ('Spore', 34),
#  ('Beyond Good & Evil', 34),
#  ("Legend of Zelda: Majora's Mask", 34),
#  ('Twisted Metal', 34),
#  ('Turok', 34),
#  ('Rock Band', 34),
#  ('Star Wars Rogue Squadron II: Rogue Leader', 34),
#  ('The Legend of Dragoon - Playstation', 34),
#  ('LEGO Star Wars III: The Clone Wars', 34),
#  ('Call of Juarez: Bound in Blood', 34),
#  ('Okami', 34),
#  ('Pure', 34),
#  ("Tom Clancy's Splinter Cell Pandora Tomorrow", 34),
#  ('Star Fox 64 3D', 33),
#  ('Resident Evil: The Umbrella Chronicles', 33),
#  ('Sonic Lost World', 33),
#  ('Mortal Kombat X', 33),
#  ('GoldenEye 007', 33),
#  ('Super Mario All Stars', 33),
#  ('Super Mario Advance 4: Super Mario Bros 3', 33),
#  ('Murdered Suspect', 33),
#  ('Need for Speed: Hot Pursuit 2', 33),
#  ('Tomb Raider Anniversary', 33),
#  ('Prey', 33),
#  ('Condemned Criminal Origins', 33),
#  ('Half Life 2', 33),
#  ('Medal of Honor: Allied Assault - PC', 33),
#  ('Dead Island - Xbox 360', 32),
#  ('Metal Gear Solid: The Twin Snakes', 32),
#  ('Sonic & Sega All-Stars Racing', 32),
#  ('Sonic Heroes', 32),
#  ('Lord of the Rings: War in the North', 32),
#  ('Just Dance 3', 32),
#  ("Baldur's Gate: Dark Alliance", 32),
#  ('Xenosaga - PlayStation 2', 32),
#  ('Far Cry - PC', 32),
#  ("Tom Clancy's Ghost Recon Advanced Warfighter", 32),
#  ('God of War 2 - PlayStation 2', 32),
#  ('Kingdom Hearts HD 1.5 Remix', 31),
#  ('Castlevania: Symphony of the Night', 31),
#  ('Nintendo 3DS - Cosmo Black', 31),
#  ('Blacksite: Area 51', 31),
#  ('The Walking Dead: Survival Instinct', 31),
#  ('Shenmue', 31),
#  ('The Walking Dead', 31),
#  ('Madden NFL 15', 31),
#  ('Valkyria Chronicles', 31),
#  ('Pokemon X', 31),
#  ('The Elder Scrolls III: Morrowind', 31),
#  ('Ninja Gaiden', 31),
#  ("Clive Barker's Jericho", 31),
#  ("Devil May Cry 3: Dante's Awakening", 31),
#  ('Warhammer 40K: Space Marine', 31),
#  ('Call of Duty: Modern Warfare 3', 30),
#  ('Resident Evil 5: Gold Edition', 30),
#  ('Perfect Dark Zero', 30),
#  ('Lollipop Chainsaw', 30),
#  ('The Darkness II', 30),
#  ('LEGO Batman 3: Beyond Gotham', 30),
#  ('Castlevania: Lament of Innocence', 30),
#  ('The Legend of Zelda', 30),
#  ('Nintendo Land', 30),
#  ('Super Street Fighter IV', 30),
#  ('Bejeweled Twist', 30),
#  ('Blur', 30),
#  ("Kirby's Epic Yarn", 30),
#  ('Soul Calibur V', 30),
#  ('Quake 4', 30),
#  ('Need for Speed: Prostreet', 30),
#  ('Fight Night Round 3', 30),
#  ('State of Emergency - PlayStation 2', 30),
#  ('Ratchet and Clank: Into the Nexus - PS3', 29),
#  ('Dead Island Riptide', 29),
#  ('Ico', 29),
#  ('Ratchet & Clank Going Commando', 29),
#  ('Metal Gear Solid 3 Snake Eater - PlayStation 2', 29),
#  ('Pinball Hall of Fame: The Williams Collection', 29),
#  ('DriveClub', 29),
#  ('Lost Planet 2', 29),
#  ('Sniper: Ghost Warrior', 29),
#  ("Assassin's Creed III: Liberation", 29),
#  ('Madden NFL 12', 29),
#  ('Bully: Scholarship Edition', 29),
#  ('Angry Birds Trilogy', 29),
#  ('Midnight Club Los Angeles', 29),
#  ('Star Wars Knights of the Old Republic - PC', 29),
#  ('Uncharted 2: Among Thieves GOTY Edition', 29),
#  ('Burnout 3 Takedown', 29),
#  ('Spider-Man - PlayStation 2', 29),
#  ('Metroid Fusion', 29),
#  ('Resident Evil 3: Nemesis', 29),
#  ('Crackdown - Xbox 360', 29),
#  ('Return to Castle Wolfenstein', 29),
#  ('LEGO The Hobbit', 28),
#  ('LEGO Harry Potter: Years 5-7', 28),
#  ('Metroid Prime 2: Echoes', 28),
#  ('Super Paper Mario', 28),
#  ('The Legend of Zelda:  Phantom Hourglass', 28),
#  ('Donkey Kong Country Returns 3D', 28),
#  ('Metro Redux - Xbox One', 28),
#  ('PS3 Journey Collection', 28),
#  ('Two Worlds 2', 28),
#  ('Metro 2033', 28),
#  ('FIFA Soccer 12', 28),
#  ('Need for Speed: Shift', 28),
#  ('Guitar Hero Aerosmith', 28),
#  ('Dungeon Siege 3', 28),
#  ('The Sims 3', 28),
#  ('Mario Party 8', 28),
#  ('Prince of Persia: Warrior Within', 28),
#  ('The Sly Collection - Playstation 3', 28),
#  ('Just Dance 4', 28),
#  ('Silent Hill: Shattered Memories', 28),
#  ('Unreal Tournament III', 28),
#  ('Ninja Gaiden II', 28),
#  ('Brütal Legend', 28),
#  ('Star Wars Jedi Knight 2: Jedi Outcast - PC', 28),
#  ("Heavy Rain: Director's Cut PS3", 27),
#  ('Metro Last Light', 27),
#  ('Paper Mario: The Thousand-Year Door', 27),
#  ('Call of Duty Advanced Warfare - Day Zero Edition', 27),
#  ('Madden NFL 10', 27),
#  ('Plants Vs. Zombies', 27),
#  ('The Simpsons Game - Nintendo 64', 27),
#  ('Metal Gear Solid: The Legacy Collection', 27),
#  ('Riddick: Assault on Dark Athena', 27),
#  ('Split / Second', 27),
#  ('LittleBigPlanet 2', 27),
#  ('Indigo Prophecy', 27),
#  ('MLB 14 The Show', 27),
#  ('Need For Speed: Underground 2', 27),
#  ('Prince of Persia: The Two Thrones', 27),
#  ('Tomb Raider Trilogy', 27),
#  ('Brain Age: Train Your Brain in Minutes a Day!', 27),
#  ('Spider-Man: Web of Shadows', 27),
#  ('Stranglehold', 27),
#  ('SSX', 27),
#  ('Street Fighter Alpha 3', 27),
#  ('Guitar Hero Metallica', 27),
#  ('The Legend of Zelda: Twilight Princess (Nintendo Selects)', 26),
#  ('Splatoon', 26),
#  ('Scarface The World Is Yours', 26),
#  ('PSPgo', 26),
#  ('Ryse: Son of Rome', 26),
#  ('Captain America: Super Soldier', 26),
#  ("Asura's Wrath", 26),
#  ('New Super Luigi U', 26),
#  ('Super Mario Advance', 26),
#  ('House of the Dead OVERKILL - Extended Cut - Playstation 3', 26),
#  ('Mario and Luigi: Dream Team', 26),
#  ('Madden NFL 11 - Nintendo 64', 26),
#  ('Angry Birds Star Wars', 26),
#  ('Forza Horizon 2 - Parent', 26),
#  ("Dragon's Dogma: Dark Arisen", 26),
#  ('Rocksmith', 26),
#  ('Spider-Man: Shattered Dimensions', 26),
#  ('Professor Layton and the Curious Village - Nintendo DS', 26),
#  ('Guild Wars 2', 26),
#  ('Killzone - PlayStation 2', 26),
#  ('Sony Twisted Metal: Black - Playstation 2', 26),
#  ('Tekken 4 - PlayStation 2', 26),
#  ('Max Payne 2: The Fall of Max Payne', 26),
#  ('Max Payne 2 The Fall of Max Payne', 26),
#  ('Jak II - PlayStation 2', 26),
#  ('True Crime: Streets of LA', 26),
#  ('Shinobi', 26),
#  ('Soul Calibur II - Gamecube', 26),
#  ('X-Men Legends', 26),
#  ('The Walking Dead: Season 2', 25),
#  ('Tales of Xillia', 25),
#  ('Sly Cooper And The Thievius Raccoonus - PlayStation 2', 25),
#  ('Ratchet & Clank - PlayStation 2', 25),
#  ('Mortal Kombat: Deadly Alliance - PlayStation 2', 25),
#  ('Just Dance 2015', 25),
#  ('Army of Two: The 40th Day', 25),
#  ('FIFA 15', 25),
#  ('SimCity - Limited Edition', 25),
#  ('Saints Row (Platinum Hits)', 25),
#  ('Lost Planet: Extreme Condition - Xbox 360', 25),
#  ('Kirby Triple Deluxe - Nintendo 3DS', 25),
#  ('Gran Turismo 6', 25),
#  ('Sniper 2: Ghost Warrior', 25),
#  ("Tom Clancy's Splinter Cell Chaos Theory", 25),
#  ('Prince of Persia Trilogy HD - Playstation 3', 25),
#  ('NIER', 25),
#  ('NBa 2K15', 25),
#  ('The Beatles: Rock Band', 25),
#  ('Starfox Adventures', 25),
#  ('The Thing', 25),
#  ('Doom', 25),
#  ('Metroid: Zero Mission', 25),
#  ('Kinect Sports', 25),
#  ('Blood Omen 2', 25),
#  ('Jak and Daxter: The Precursor Legacy', 25),
#  ('Animal Crossing: Wild World', 25),
#  ('TimeSplitters 2', 25),
#  ('Guitar Hero 5', 25),
#  ('Tekken Tag Tournament - PlayStation 2', 25),
#  ('Resident Evil: Outbreak - PlayStation 2', 25),
#  ('Call of Duty', 25),
#  ("Tom Clancy's HAWX", 24),
#  ('DuckTales: Remastered', 24),
#  ('Tales of Symphonia - Gamecube', 24),
#  ('007 Legends', 24),
#  ('Terminator: Salvation', 24),
#  ('Lost Planet 3', 24),
#  ('Mad Catz Rock Band 3', 24),
#  ('Super Street Fighter IV: 3D Edition - Nintendo 3DS', 24),
#  ('Namco Museum', 24),
#  ('Super Mario Bros. 3', 24),
#  ('Fight Night Champion - Playstation 3', 24),
#  ('Killzone: Mercenary', 24),
#  ('Dirt 3', 24),
#  ('Condemned 2: Bloodshot', 24),
#  ('Ryse: Son of Rome Day One Edition - Xbox One', 24),
#  ("Assassin's Creed Rogue", 24),
#  ('Donkey Kong 64 - Nintendo 64', 24),
#  ('Mass Effect Trilogy', 24),
#  ('NBA 2K13', 24),
#  ('Forza Motorsport 4', 24),
#  ('Destroy All Humans', 24),
#  ('The Elder Scrolls IV: Oblivion - Game of the Year Edition', 24),
#  ("Assassin's Creed Ezio Trilogy Edition", 24),
#  ('The Amazing Spider-Man 2', 24),
#  ('MotorStorm - Playstation 3', 24),
#  ('Eternal Sonata', 24),
#  ('Sacred 2: Fallen Angel', 24),
#  ('The World Ends With You', 24),
#  ("Brothers in Arms: Hell's Highway", 24),
#  ('Gran Turismo', 24),
#  ('Perfect Dark', 24),
#  ('Grand Theft Auto Vice City Stories', 24),
#  ('Dead or Alive 3', 24),
#  ('Disney INFINITY 2.0 Edition', 23),
#  ('Nintendo 2DS', 23),
#  ('Green Lantern: Rise of the Manhunters', 23),
#  ('Spider-Man 3', 23),
#  ('James Bond 007: Blood Stone', 23),
#  ('Castlevania: Lords of Shadow 2', 23),
#  ('Kingdom Hearts Re:Chain of Memories', 23),
#  ('Justice League Heroes', 23),
#  ('Diablo Battle Chest', 23),
#  ('Metal Slug Anthology', 23),
#  ('Dishonored: Game of the Year Edition', 23),
#  ('Crash Bandicoot Wrath of Cortex', 23),
#  ('WWE 2K14', 23),
#  ('PlayStation TV', 23),
#  ("Conker's Bad Fur Day", 23),
#  ('Kid Icarus: Uprising', 23),
#  ('The Godfather II', 23),
#  ('The Chronicles of Riddick: Escape From Butcher Bay', 23),
#  ('Tekken Tag Tournament 2', 23),
#  ('Sniper Elite 2', 23),
#  ('Mario Party 9', 23),
#  ('Guitar Hero 2', 23),
#  ('Wet', 23),
#  ('Parasite Eve', 23),
#  ('Star Wars The Old Republic', 23),
#  ('Silent Hill 4 The Room', 23),
#  ('Devil May Cry 2', 23),
#  ('Gran Turismo 4 - PlayStation 2', 23),
#  ('Lego Star Wars', 23),
#  ('The Getaway - PlayStation 2', 23),
#  ('WarCraft III: Reign of Chaos - PC/Mac', 23),
#  ('Burnout Revenge', 23),
#  ('Grand Theft Auto III', 23),
#  ('Deus Ex', 23),
#  ('Ninja Gaiden Sigma 2', 23),
#  ('Area 51', 23),
#  ('XIII', 23),
#  ("Tony Hawk's Underground 2", 23),
#  ('The Simpsons: Road Rage', 23),
#  ('ESPN NFL 2K5', 23),
#  ('The Walking Dead Game of the Year', 22),
#  ('Borderlands: The Pre-Sequel', 22),
#  ('Sunset Overdrive Day One Edition - Xbox One', 22),
#  ('Sony PlayStation 98175 Ratchet & Clank: All 4 One PS3', 22),
#  ('Star Wars Battlefront - PlayStation 2', 22),
#  ('Kingdom Hearts 3D Dream Drop Distance', 22),
#  ('Kingdom Hearts: Birth by Sleep - Sony PSP', 22),
#  ('3D Dot Game Heroes - Playstation 3', 22),
#  ('Mortal Kombat 4', 22),
#  ('Mortal Kombat II', 22),
#  ('Zelda II: The Adventure of Link', 22),
#  ("Army of TWO The Devil's Cartel", 22),
#  ('Mag Online Only - Playstation 3', 22),
#  ('EA Sports Active', 22),
#  ('Dead or Alive Dimensions', 22),
#  ('Risen', 22),
#  ("Uncharted 3: Drake'S Deception Game Of The Year Digital Edition", 22),
#  ('Command & Conquer: Red Alert 3', 22),
#  ('The Legend of Spyro: Dawn of the Dragon', 22),
#  ('MLB 12 The Show', 22),
#  ('Bejeweled 3', 22),
#  ('Sports Champions - Playstation 3', 22),
#  ('Star Ocean: The Last Hope International - Playstation 3', 22),
#  ('Conan', 22),
#  ('Thor: God of Thunder', 22),
#  ('StarCraft Battle Chest', 22),
#  ('Forza Horizon', 22),
#  ("Eternal Darkness: Sanity's Requiem", 22),
#  ("Resident Evil: Director's Cut", 22),
#  ('Grand Theft Auto: Chinatown Wars', 22),
#  ('Call of Duty Finest Hour', 22),
#  ('Stuntman', 22),
#  ('ModNation Racers', 22),
#  ('Myst 3: Exile', 22),
#  ("Baldur's Gate II: Shadows of Amn", 22),
#  ('Gran Turismo 5 Prologue', 21),
#  ('Tales of Graces f', 21),
#  ('Contra: Shattered Soldier', 21),
#  ('Super Princess Peach', 21),
#  ('The Legend of Zelda: Spirit Tracks', 21),
#  ('Resident Evil: The Darkside Chronicles', 21),
#  ('Game Boy Player', 21),
#  ('PS3 Starhawk', 21),
#  ("Yoshi's Island: Super Mario Advance 3", 21),
#  ('Super Mario Galaxy (Nintendo Selects)', 21),
#  ('Super Mario Bros. Deluxe', 21),
#  ('Super Mario Bros. 2', 21),
#  ('Lost Odyssey - Xbox 360', 21),
#  ('Deadly Premonition - Xbox 360', 21),
#  ('God Of War: Chains Of Olympus', 21),
#  ('UFC', 21),
#  ('Pikmin 3', 21),
#  ('MLB 13 The Show', 21),
#  ('Nintendo DS Lite Onyx Black', 21),
#  ('Ninja Gaiden 3', 21),
#  ('Two Worlds', 21),
#  ('Legendary', 21),
#  ("The Legend of Zelda: Majora's Mask", 21),
#  ('Fatal Frame', 21),
#  ('Metroid Prime 3: Corruption', 21),
#  ('Tekken 5', 21),
#  ('JSRF- Jet Set Radio Future', 21),
#  ('Neverwinter Nights', 21),
#  ('Silent Hill', 21),
#  ('Project Gotham Racing', 21),
#  ('Resonance of Fate', 21),
#  ('Legacy of Kain: Soul Reaver 2', 21),
#  ('Test Drive Unlimited 2', 21),
#  ('F.E.A.R.: First Encounter Assault Recon - PC', 21),
#  ('Brothers in Arms Road to Hill 30', 21),
#  ('No More Heroes', 21),
#  ('Guitar Hero: Warriors of Rock', 21),
#  ('Zoom for Kinect - Xbox 360', 21),
#  ('Spider-Man', 21),
#  ('Dead or Alive Xtreme Beach Volleyball', 21),
#  ('The Suffering', 21),
#  ('Battlefield: Bad Company - Nintendo 64', 21),
#  ("Halo 2: Limited Collector's Edition", 21),
#  ('Battlefield 1942', 21),
#  ('The Simpsons Hit & Run', 21),
#  ('Freedom Fighters - Nintendo 64', 21),
#  ('Unreal 2: The Awakening', 21),
#  ('Golden Sun', 21),
#  ("Tony Hawk's Pro Skater 4", 21),
#  ('Lords of the Fallen: Limited Edition - PlayStation 4', 20),
#  ('Ratchet & Clank Up Your Arsenal - PlayStation 2', 20),
#  ('Red Dead Redemption Undead', 20),
#  ('The Legend of Zelda: Skyward Sword', 20),
#  ('Castlevania: Dawn of Sorrow', 20),
#  ('Black', 20),
#  ("Yoshi's New Island - Nintendo 3DS", 20),
#  ('Super Smash Bros.', 20),
#  ('Super Mario All-Stars: Limited Edition', 20),
#  ('LittleBigPlanet Karting - Playstation 3', 20),
#  ('NBA 2K11', 20),
#  ('WWE Legends of WrestleMania', 20),
#  ("Hunted: The Demon's Forge", 20),
#  ('Grand Theft Auto IV & Episodes from Liberty City: The Complete Edition',
#   20),
#  ('Kane and Lynch 2: Dog Days', 20),
#  ('Madden NFL 09', 20),
#  ('Haze - Playstation 3', 20),
#  ('Namco Ace Combat 4 Shattered Skies', 20),
#  ('Call of Duty 2: Big Red One', 20),
#  ('WWE All-Stars', 20),
#  ('Dragon Quest IX: Sentinels of the Starry Skies', 20),
#  ('Battlefield: Bad Company', 20),
#  ('Onimusha Warlords', 20),
#  ('Mech Assault - Xbox', 20),
#  ('True Crime: New York City', 20),
#  ('SOCOM: US Navy Seals', 20),
#  ("Oddworld: Munch's Oddysee (Xbox)", 20),
#  ('WWE SmackDown! Here Comes the Pain - PlayStation 2', 20),
#  ('Tales of Vesperia', 19),
#  ('Dark Cloud', 19),
#  ('XCOM: Enemy Within', 19),
#  ('The Wolf Among Us', 19),
#  ("Yoshi's Island DS", 19),
#  ('Warhawk', 19),
#  ('Kane & Lynch: Dead Men', 19),
#  ('F-Zero GX', 19),
#  ('Sonic Advance', 19),
#  ("Sonic Adventure DX Director's Cut", 19),
#  ("Super Mario World 2: Yoshi's Island", 19),
#  ('Super Mario Kart', 19),
#  ('Mario Kart 64', 19),
#  ('Super Mario Bros.', 19),
#  ('Sonic the Hedgehog 3', 19),
#  ('Band Hero featuring Taylor Swift', 19),
#  ('inFAMOUS Collection - Playstation 3', 19),
#  ('Blue Dragon - Xbox 360', 19),
#  ('Dark Void', 19),
#  ('Viking: Battle for Asgard', 19),
#  ('WWE 2K15', 19),
#  ('WWE Smackdown vs Raw 2010', 19),
#  ('Lord of the Rings The Two Towers - PlayStation 2', 19),
#  ('Jak & Daxter Collection - Playstation 3', 19),
#  ('Golden Axe:  Beast Rider', 19),
#  ("AKIBA'S TRIP: Undead & Undressed", 19),
#  ("Kirby's Dream Collection: Special Edition", 19),
#  ('Animal Crossing: City Folk', 19),
#  ('Driver: San Francisco', 19),
#  ("Mario & Luigi Bowser's Inside Story", 19),
#  ("WWE Smackdown vs Raw '09", 19),
#  ('Grid', 19),
#  ('Tekken 3', 19),
#  ('Mega Man X Collection - PlayStation 2', 19),
#  ('Super Metroid', 19),
#  ('Fuse', 19),
#  ('Sims', 19),
#  ('Earth Defense Force: Insect Armageddon', 19),
#  ('The Smurfs 2', 19),
#  ('Black & White', 19),
#  ('Dead Space Extraction', 19),
#  ('Too Human - Xbox 360', 19),
#  ('Grand Theft Auto: Vice City - PC', 19),
#  ('Iron Man', 19),
#  ('Spider-Man 2 - PlayStation 2', 19),
#  ('Driv3r', 19),
#  ("Indiana Jones and the Emperor's Tomb", 19),
#  ("Tony Hawk's Underground", 19),
#  ('Gauntlet: Dark Legacy', 19),
#  ('Diablo 2', 19),
#  ('Motorstorm Apocalypse', 18),
#  ('Motorstorm: Pacific Rift - Playstation 3', 18),
#  ('LEGO Indiana Jones 2: The Adventure Continues', 18),
#  ('Metroid Prime Hunters', 18),
#  ('Resident Evil: The Mercenaries 3D', 18),
#  ('Dead to Rights Retribution', 18),
#  ('Disney INFINITY: Marvel Super Heroes (2.0 Edition) - Not Machine Specific',
#   18),
#  ('Rayman Raving Rabbids', 18),
#  ('Mario Party DS', 18),
#  ('9 Hours, 9 Persons, 9 Doors', 18),
#  ('SOCOM 4: U.S. Navy Seals', 18),
#  ('ModNation Racers: Road Trip', 18),
#  ("WWE '12", 18),
#  ('WWE Smackdown vs. Raw 2008', 18),
#  ('UFC Undisputed 3', 18),
#  ('Castlevania: Lords of Shadow - Mirror of Fate HD', 18),
#  ("Zero Escape: Virtue's Last Reward", 18),
#  ('Soldier Of Fortune: Payback', 18),
#  ('Sports Champions 2 - Playstation 3', 18),
#  ('PS3 Everybody Dance', 18),
#  ('Dark Messiah: Might & Magic', 18),
#  ('Metroid', 18),
#  ('Marvel Vs. Capcom 2', 18),
#  ('Resident Evil 3 Nemesis', 18),
#  ('Warioware: Touched! - Nintendo DS', 18),
#  ('Rogue Galaxy - PlayStation 2', 18),
#  ('Soulcalibur 3 - PlayStation 2', 18),
#  ('Civilization 3', 18),
#  ("Rainbow Six 3 (Tom Clancy's) - Xbox", 18),
#  ('Godfather the Game', 18),
#  ('Hunter: The Reckoning', 18),
#  ('Unreal Championship (Xbox)', 18),
#  ('Pokémon - Black Version', 18),
#  ('Age of Mythology', 18),
#  ('Child Of Eden', 18),
#  ('Soldier of Fortune II Double Helix', 18),
#  ('Unreal Tournament', 18),
#  ('Pokémon Black Version 2', 17),
#  ('Silent Hill HD Collection', 17),
#  ('Afro Samurai', 17),
#  ('Bionic Commando', 17),
#  ('Transformers Rise of the Dark Spark', 17),
#  ('Tales of Xillia 2', 17),
#  ('Castlevania: Circle of the Moon', 17),
#  ('Mortal Kombat Armageddon - PlayStation 2', 17),
#  ('Mortal Kombat Deception - PlayStation 2', 17),
#  ('The Elder Scrolls Online', 17),
#  ('Paper Mario', 17),
#  ('Sega Genesis Collection', 17),
#  ('Pac-Man and the Ghostly Adventures', 17),
#  ('Batman Arkham City: Armored Edition', 17),
#  ('Mega Man 2 - Nintendo NES', 17),
#  ('Game Boy Color', 17),
#  ('Sonic the Hedgehog 2', 17),
#  ('Soul Sacrifice Delta', 17),
#  ('Punch-Out!!', 17),
#  ('Disney Universe', 17),
#  ('The Witcher - Enhanced Edition', 17),
#  ('Shin Megami Tensei: Persona 4 - PlayStation 2', 17),
#  ("Metroid Prime Trilogy: Collector's Edition", 17),
#  ('Forza Motorsport 5', 17),
#  ('Unit 13', 17),
#  ('Dark Cloud 2 - PlayStation 2', 17),
#  ('Medal of Honor: Pacific Assault - PC', 17),
#  ('Pokemon White Version 2 - Nintendo DS', 17),
#  ('Tales of the Abyss', 17),
#  ('World of Warcraft', 17),
#  ('Kinect Star Wars - Xbox 360', 17),
#  ('Wolfenstein 3D', 17),
#  ('The Elder Scrolls 3: Morrowind', 17),
#  ('Forza Motorsport 2 - Xbox 360', 17),
#  ('Avatar', 17),
#  ('Killer Instinct', 17),
#  ('House of the Dead 2 & 3 Return', 17),
#  ('Transformers: Revenge of the Fallen', 17),
#  ('Halo Wars - Xbox 360', 17),
#  ('Daxter', 17),
#  ("Tony Hawk's Pro Skater 2", 17),
#  ('Xenogears - PlayStation', 17),
#  ('Killer is Dead', 17),
#  ('GTA Liberty City Stories', 17),
#  ('Folklore - Playstation 3', 17),
#  ('Hitman Blood Money', 17),
#  ('Unreal Tournament 2003 - PC', 17),
#  ('The Wonderful 101', 17),
#  ('Halo Wars', 17),
#  ('Driver 2', 17),
#  ('Dead or Alive 4', 17),
#  ('Urbz: Sims In The City', 17),
#  ('Crimson Skies: High Road to Revenge', 17),
#  ('S.T.A.L.K.E.R.: Shadow of Chernobyl', 17),
#  ('The Fight: Lights Out - Playstation 3', 17),
#  ('Xenosaga Episode II: Jenseits Von Gut und Bose - PlayStation 2', 17),
#  ('Diablo', 17),
#  ('Half-Life: Counter-Strike - PC', 17),
#  ('MVP Baseball 2005', 17),
#  ('Mafia - PC', 17),
#  ('Time Splitters: Future Perfect', 16),
#  ('The Lord of the Rings The Third Age', 16),
#  ('Socom U.S. Navy Seals: Confrontation', 16),
#  ('Command & Conquer 3: Tiberium Wars - Nintendo 64', 16),
#  ('Mario Party 10', 16),
#  ('Super Castlevania IV', 16),
#  ('Street Fighter II', 16),
#  ('Super Mario Bros. - Classic NES Series', 16),
#  ('Bound by Flame', 16),
#  ('Puzzle Quest', 16),
#  ('White Knight Chronicles International Edition - Playstation 3', 16),
#  ('Psychonauts', 16),
#  ('The Sims 3: Pets', 16),
#  ("American McGee's Alice - PC", 16),
#  ('Yakuza 4 - Playstation 3', 16),
#  ('Captain Toad:  Treasure Tracker', 16),
#  ('Half-Life: Game of the Year Edition - PC', 16),
#  ('Time Splitters 2', 16),
#  ('Star Trek', 16),
#  ('Star Wars Battlefront - Xbox', 16),
#  ('Jeopardy', 16),
#  ('Diddy Kong Racing', 16),
#  ('Big Brain Academy', 16),
#  ('Warcraft III Battle Chest - PC/Mac', 16),
#  ('Forza Motorsport 3 - Xbox 360', 16),
#  ('SSX 3', 16),
#  ('Yaniba: Ninja Gaiden Z', 16),
#  ('Turning Point: Fall of Liberty', 16),
#  ('Just Dance Kids 2014', 16),
#  ("Clive Barker's Undying", 16),
#  ('Overlord', 16),
#  ('Dirt 2', 16),
#  ('Shift 2 - Unleashed', 16),
#  ('X-Men Legends II Rise of the Apocalypse', 16),
#  ('Frontlines: Fuel of War', 16),
#  ('Hulk', 16),
#  ('Pokemon SoulSilver Version', 16),
#  ('Mario & Luigi: Partners In Time', 16),
#  ('Dungeon Siege', 16),
#  ('Madden NFL 2005 - PS2', 16),
#  ('Resident Evil 5 - PC', 15),
#  ('Mini Ninjas', 15),
#  ('MLB 15: The Show - Parent', 15),
#  ('Cars 2', 15),
#  ('Marvel vs. Capcom 2', 15),
#  ('Ninja Gaiden Black', 15),
#  ('Untold Legends:  Dark Kingdom - Playstation 3', 15),
#  ('Tearaway', 15),
#  ('Mario & Sonic Sochi 2014 Olympic Winter Games', 15),
#  ('Shadow The Hedgehog', 15),
#  ('Rayman Raving Rabbids 2', 15),
#  ('Castlevania', 15),
#  ('Sonic Rush', 15),
#  ('Operation Flashpoint: Red River', 15),
#  ('El Shaddai: Ascension of the Metatron', 15),
#  ('Dead or Alive 5', 15),
#  ('Skies of Arcadia : Legends', 15),
#  ('WWE Smackdown vs Raw', 15),
#  ('Zumba Fitness', 15),
#  ('Kirby & The Rainbow Curse', 15),
#  ('Tomodachi Life', 15),
#  ('Blades of Time', 15),
#  ('Freelancer - PC', 15),
#  ('Aliens Versus Predator 2', 15),
#  ('Kinect Sports Season Two', 15),
#  ('Star Trek Online', 15),
#  ('Mario and Sonic at the Olympic Winter Games', 15),
#  ('Fight Night: Round 4 - Nintendo 64', 15),
#  ('Resident Evil Deadly Silence - Nintendo DS', 15),
#  ('Professor Layton and the Diabolical Box', 15),
#  ('Banjo-Kazooie', 15),
#  ('Half-Life', 15),
#  ('Dead Island - Playstation 3', 15),
#  ('Superman Returns', 15),
#  ('Age of Empires III', 15),
#  ('Odin Sphere - PlayStation 2', 15),
#  ('Cryostasis', 15),
#  ('Scribblenauts Unlimited', 15),
#  ('Mark of Kri - PlayStation 2', 15),
#  ('Resistance: Retribution', 15),
#  ("Sid Meier's Civilization IV", 15),
#  ('Silent Hill 2: Restless Dreams', 15),
#  ('Jak 3 - PlayStation 2', 15),
#  ('NBA Street Vol 2', 15),
#  ('My Word Coach', 15),
#  ('Maximo Ghosts To Glory - PlayStation 2', 15),
#  ('Operation Flashpoint 2: Dragon Rising', 15),
#  ('Grand Theft Auto: Liberty City Stories', 15),
#  ('Roller Coaster Tycoon', 15),
#  ('Medal of Honor Frontline - Xbox', 15),
#  ('Just Dance Kids 2', 15),
#  ('Titan Quest - PC', 15),
#  ('Sonic Adventure 2', 15),
#  ('Guild Wars Game of the Year - PC', 15),
#  ('Battlefield: Vietnam - PC', 15),
#  ('Unreal Tournament 2004', 15),
#  ('Katamari Damacy', 15),
#  ('WWE Wrestlemania XIX', 15),
#  ('Virtua Fighter 4 - PlayStation 2', 15),
#  ('Red Steel 2', 14),
#  ...]

# %%
# Make recommendations
new_ratings = {'Destiny': 4,
               "Assassin's Creed III": 5, 
               'Red Dead Redemption': 5,
               'Battlefield 4': 3}

get_recommendations(new_ratings, ratings_df, K=2, alpha=0.01, beta=0.02, iterations=500)
# Out:
# Time taken: 346.77094888687134 seconds
#
# Based on your preferences:
#  {'Destiny': 4, "Assassin's Creed III": 5, 'Red Dead Redemption': 5, 'Battlefield 4': 3}
# We Suggest:
# product_title
# Transformers Rise of the Dark Spark     9.034580
# Velvet Assassin                         8.811642
# Unreal II: The Awakening - Xbox         8.734482
# Guild Wars Factions                     8.629912
# SWAT 3                                  8.529739
# Phantasy Star Online, Episode I & II    8.505751
# Pikachu Hard Pouch                      8.309053
# The Sims Deluxe Edition - PC            8.275162
# Shaun White Snowboarding                8.198683
# Blade Runner - PC                       8.092065
# WWE Wrestlemania X8                     8.038657
# Earth & Beyond                          7.983707
# Killing Floor - PC                      7.647993
# Tom Clancy's Rainbow Six Lockdown       7.610660
# Shaun White Skateboarding               7.580981
# Name: 0, dtype: float64
